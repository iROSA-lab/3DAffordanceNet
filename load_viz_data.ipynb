# %%
# Copyright (c) Gorilla-Lab. All rights reserved.
import os
from os.path import join as opj
import torch
import torch.nn as nn
import numpy as np

import open3d as o3d
from open3d.web_visualizer import draw
import matplotlib.pyplot as plt
import trimesh

# from gorilla.config import Config
# import models
# import loss
from utils import *
from dataset import *
# import argparse

# %%
# set_random_seed(0)

data = dict(
    data_root='data_root',
    partial=False,
    category=['grasp', 'contain', 'lift', 'openable', 'layable', 'sittable',
              'support', 'wrap_grasp', 'pourable', 'move', 'displaY', 'pushable', 'pull',
              'listen', 'wear', 'press', 'cut', 'stab']
)

afford_cat = data['category']
data_root = data['data_root']
partial = data['partial']
aff_train_set = AffordNetDataset(data_root, 'train', partial=partial)
aff_val_set = AffordNetDataset(data_root, 'val', partial=partial)
print("Loaded dataset with {} training samples and {} validation samples".format(len(aff_train_set), len(aff_val_set)))
# Out:
# Loaded dataset with 16082 training samples and 2285 validation samples

# %%
# pick a random datapoint
while(1):
    rand_index = np.random.randint(0, len(aff_train_set.all_data))#9532
    data_temp = aff_train_set.all_data[rand_index]
    print("Choosing random index: ", rand_index)
    if data_temp['semantic class'] == "Mug":
        break
# Out:
# Choosing random index:  10440
# Choosing random index:  15256
# Choosing random index:  6628
# Choosing random index:  15208
# Choosing random index:  4966
# Choosing random index:  14320
# Choosing random index:  14784
# Choosing random index:  6968
# Choosing random index:  5236
# Choosing random index:  9618
# Choosing random index:  6902
# Choosing random index:  4765
# Choosing random index:  827
# Choosing random index:  1739
# Choosing random index:  15476
# Choosing random index:  8477
# Choosing random index:  9944
# Choosing random index:  15060
# Choosing random index:  11272
# Choosing random index:  3997
# Choosing random index:  4935
# Choosing random index:  8670
# Choosing random index:  990
# Choosing random index:  9680
# Choosing random index:  8996
# Choosing random index:  1641
# Choosing random index:  2339
# Choosing random index:  9254
# Choosing random index:  1697
# Choosing random index:  11093
# Choosing random index:  5125
# Choosing random index:  13947
# Choosing random index:  3810
# Choosing random index:  4079
# Choosing random index:  5238
# Choosing random index:  2061
# Choosing random index:  4137
# Choosing random index:  12198
# Choosing random index:  10610
# Choosing random index:  15778
# Choosing random index:  7650
# Choosing random index:  16019
# Choosing random index:  6072
# Choosing random index:  10972
# Choosing random index:  7428
# Choosing random index:  8802
# Choosing random index:  14842
# Choosing random index:  10043
# Choosing random index:  5146
# Choosing random index:  14066
# Choosing random index:  5147
# Choosing random index:  2259
# Choosing random index:  2964
# Choosing random index:  9997
# Choosing random index:  2915
# Choosing random index:  2800
# Choosing random index:  11216
# Choosing random index:  14395
# Choosing random index:  6586
# Choosing random index:  9708
# Choosing random index:  2964
# Choosing random index:  12432
# Choosing random index:  8071
# Choosing random index:  3204
# Choosing random index:  11703
# Choosing random index:  9587
# Choosing random index:  7953
# Choosing random index:  5078
# Choosing random index:  4448
# Choosing random index:  3132
# Choosing random index:  15140
# Choosing random index:  11228
# Choosing random index:  11919
# Choosing random index:  921
# Choosing random index:  6027
# Choosing random index:  4956
# Choosing random index:  15711
# Choosing random index:  146
# Choosing random index:  3071
# Choosing random index:  5315
# Choosing random index:  8086
# Choosing random index:  4816
# Choosing random index:  12398
# Choosing random index:  2471
# Choosing random index:  7965
# Choosing random index:  10398
# Choosing random index:  3614
# Choosing random index:  13494
# Choosing random index:  8847
# Choosing random index:  224
# Choosing random index:  2934
# Choosing random index:  12020
# Choosing random index:  14679
# Choosing random index:  3901
# Choosing random index:  2523
# Choosing random index:  827
# Choosing random index:  15377
# Choosing random index:  11674
# Choosing random index:  1041
# Choosing random index:  3336
# Choosing random index:  11978
# Choosing random index:  9604
# Choosing random index:  14933
# Choosing random index:  8507
# Choosing random index:  4199
# Choosing random index:  9705
# Choosing random index:  12191
# Choosing random index:  8394
# Choosing random index:  14397
# Choosing random index:  1849
# Choosing random index:  6381
# Choosing random index:  10387
# Choosing random index:  14041
# Choosing random index:  6562
# Choosing random index:  14717
# Choosing random index:  2473
# Choosing random index:  5556
# Choosing random index:  12446
# Choosing random index:  5790
# Choosing random index:  15245
# Choosing random index:  6741
# Choosing random index:  287
# Choosing random index:  4974
# Choosing random index:  4106
# Choosing random index:  7745
# Choosing random index:  4120
# Choosing random index:  15924
# Choosing random index:  14409
# Choosing random index:  15493
# Choosing random index:  8455
# Choosing random index:  15060
# Choosing random index:  13567
# Choosing random index:  5563
# Choosing random index:  15732
# Choosing random index:  5676
# Choosing random index:  3727
# Choosing random index:  283
# Choosing random index:  12140
# Choosing random index:  424
# Choosing random index:  9895
# Choosing random index:  3623
# Choosing random index:  11304
# Choosing random index:  14792
# Choosing random index:  5610
# Choosing random index:  3609
# Choosing random index:  10929
# Choosing random index:  2704
# Choosing random index:  11339
# Choosing random index:  13767
# Choosing random index:  314
# Choosing random index:  12371
# Choosing random index:  7670
# Choosing random index:  4264
# Choosing random index:  13194
# Choosing random index:  11041
# Choosing random index:  12516
# Choosing random index:  7220
# Choosing random index:  7853
# Choosing random index:  5789
# Choosing random index:  627
# Choosing random index:  9917
# Choosing random index:  11931
# Choosing random index:  8919
# Choosing random index:  15201
# Choosing random index:  11867
# Choosing random index:  8006
# Choosing random index:  9851
# Choosing random index:  9726
# Choosing random index:  10178
# Choosing random index:  5084
# Choosing random index:  1468
# Choosing random index:  3995
# Choosing random index:  2673
# Choosing random index:  5086
# Choosing random index:  5683
# Choosing random index:  14794
# Choosing random index:  7042
# Choosing random index:  15581
# Choosing random index:  8875
# Choosing random index:  807
# Choosing random index:  2627
# Choosing random index:  9004
# Choosing random index:  2962
# Choosing random index:  10886
# Choosing random index:  4686
# Choosing random index:  7822
# Choosing random index:  12009
# Choosing random index:  14593
# Choosing random index:  9886
# Choosing random index:  3472
# Choosing random index:  12395
# Choosing random index:  3411
# Choosing random index:  5002
# Choosing random index:  3456
# Choosing random index:  10013
# Choosing random index:  2837
# Choosing random index:  5512
# Choosing random index:  2050
# Choosing random index:  16015
# Choosing random index:  11907
# Choosing random index:  12441
# Choosing random index:  10797
# Choosing random index:  10789
# Choosing random index:  5027
# Choosing random index:  8903
# Choosing random index:  6342
# Choosing random index:  4328
# Choosing random index:  12047
# Choosing random index:  3865
# Choosing random index:  5776
# Choosing random index:  4291
# Choosing random index:  4699
# Choosing random index:  9140
# Choosing random index:  2375
# Choosing random index:  12496
# Choosing random index:  15248
# Choosing random index:  23
# Choosing random index:  12629
# Choosing random index:  2640
# Choosing random index:  10864
# Choosing random index:  13147
# Choosing random index:  2582
# Choosing random index:  7015
# Choosing random index:  9035
# Choosing random index:  3364
# Choosing random index:  15979
# Choosing random index:  1168
# Choosing random index:  2024
# Choosing random index:  4426
# Choosing random index:  4060
# Choosing random index:  311
# Choosing random index:  1032
# Choosing random index:  5476
# Choosing random index:  6047
# Choosing random index:  9867
# Choosing random index:  742
# Choosing random index:  6394
# Choosing random index:  14279
# Choosing random index:  4194
# Choosing random index:  14290
# Choosing random index:  14849
# Choosing random index:  12994
# Choosing random index:  3187
# Choosing random index:  12283
# Choosing random index:  7186
# Choosing random index:  4093
# Choosing random index:  2722
# Choosing random index:  15680
# Choosing random index:  6296
# Choosing random index:  3410
# Choosing random index:  5506
# Choosing random index:  14873
# Choosing random index:  6653
# Choosing random index:  5143
# Choosing random index:  12386
# Choosing random index:  16025
# Choosing random index:  14415
# Choosing random index:  15413
# Choosing random index:  13768
# Choosing random index:  7053
# Choosing random index:  1115
# Choosing random index:  10435
# Choosing random index:  13277
# Choosing random index:  15733
# Choosing random index:  3852
# Choosing random index:  2409
# Choosing random index:  266
# Choosing random index:  1157
# Choosing random index:  8336
# Choosing random index:  4779
# Choosing random index:  8923
# Choosing random index:  2533
# Choosing random index:  7646
# Choosing random index:  8717
# Choosing random index:  642
# Choosing random index:  14066
# Choosing random index:  12726
# Choosing random index:  4442
# Choosing random index:  2765
# Choosing random index:  8666
# Choosing random index:  11357
# Choosing random index:  2206
# Choosing random index:  15870
# Choosing random index:  13921
# Choosing random index:  2869
# Choosing random index:  10864
# Choosing random index:  3645
# Choosing random index:  11841
# Choosing random index:  15068
# Choosing random index:  14207
# Choosing random index:  3966
# Choosing random index:  8121
# Choosing random index:  8390
# Choosing random index:  13029
# Choosing random index:  7789
# Choosing random index:  11875
# Choosing random index:  3621
# Choosing random index:  14533
# Choosing random index:  15692
# Choosing random index:  4993
# Choosing random index:  10841
# Choosing random index:  15884
# Choosing random index:  1289
# Choosing random index:  6807
# Choosing random index:  14299
# Choosing random index:  5664
# Choosing random index:  13712
# Choosing random index:  11696
# Choosing random index:  1763
# Choosing random index:  6255
# Choosing random index:  5621
# Choosing random index:  8207
# Choosing random index:  15589
# Choosing random index:  1131
# Choosing random index:  1588
# Choosing random index:  2100
# Choosing random index:  1180
# Choosing random index:  11507
# Choosing random index:  10198
# Choosing random index:  15142
# Choosing random index:  11955
# Choosing random index:  1507
# Choosing random index:  12622
# Choosing random index:  12817
# Choosing random index:  10222
# Choosing random index:  7259
# Choosing random index:  9947
# Choosing random index:  12659
# Choosing random index:  855
# Choosing random index:  2774
# Choosing random index:  12091
# Choosing random index:  14087
# Choosing random index:  14449
# Choosing random index:  511
# Choosing random index:  12753
# Choosing random index:  5291
# Choosing random index:  14435
# Choosing random index:  12577
# Choosing random index:  7427
# Choosing random index:  6670
# Choosing random index:  14999
# Choosing random index:  14032
# Choosing random index:  2347
# Choosing random index:  14916
# Choosing random index:  15249
# Choosing random index:  7795
# Choosing random index:  9883
# Choosing random index:  8895
# Choosing random index:  12087
# Choosing random index:  4825
# Choosing random index:  13018
# Choosing random index:  13232
# Choosing random index:  2885
# Choosing random index:  5537
# Choosing random index:  8034
# Choosing random index:  4048
# Choosing random index:  15705
# Choosing random index:  6417
# Choosing random index:  15501
# Choosing random index:  15692
# Choosing random index:  14958
# Choosing random index:  11820
# Choosing random index:  9501

# %%
print("Shape id ", data_temp['shape_id'], "\nSemantic class: ", data_temp['semantic class'])
print("All affordances: ", data_temp["affordance"])
print("Num affordances: ", len(data_temp["affordance"]))
# Out:
# Shape id  dcec634f18e12427c2c72e575af174cd
# Semantic class:  Mug
# All affordances:  ['grasp', 'contain', 'lift', 'openable', 'layable', 'sittable', 'support', 'wrap_grasp', 'pourable', 'move', 'displaY', 'pushable', 'pull', 'listen', 'wear', 'press', 'cut', 'stab']
# Num affordances:  18

# %%
pcl = data_temp['data_info']['coordinate']
# Viz pcl with o3d
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(pcl)
# color black
pcd.paint_uniform_color([0, 0, 0])
# viz in jupyter nb
print("Drawing pcd with %d points", len(pcl))
draw(pcd)
# Out:
# Drawing pcd with %d points 2048
# [Open3D INFO] Window window_32 created.
# WebVisualizer(window_uid='window_32')

# %%
# get pcls of all labels
labels_list = []
scores_list = []
for key in data_temp['data_info']['label'].keys():
    labels = data_temp['data_info']['label'][key]
    scores = labels.sum()
    print("Label: ", key, " Score: ", scores)
    labels_list.append(labels)
    scores_list.append(scores)
# Out:
# Label:  grasp  Score:  68.00398
# Label:  contain  Score:  235.93713
# Label:  lift  Score:  0.0
# Label:  openable  Score:  0.0
# Label:  layable  Score:  0.0
# Label:  sittable  Score:  0.0
# Label:  support  Score:  0.0
# Label:  wrap_grasp  Score:  199.07465
# Label:  pourable  Score:  205.49992
# Label:  move  Score:  0.0
# Label:  displaY  Score:  0.0
# Label:  pushable  Score:  0.0
# Label:  pull  Score:  0.0
# Label:  listen  Score:  0.0
# Label:  wear  Score:  0.0
# Label:  press  Score:  0.0
# Label:  cut  Score:  0.0
# Label:  stab  Score:  0.0

# %%
labels_list = np.array(labels_list)
scores_list = np.array(scores_list)
# Get max 4 labels and viz
best_score_ids = np.argsort(scores_list)[-4:]
print("Best labels: ")
for best_score_id in best_score_ids:
    print(list(data_temp['data_info']['label'].keys())[best_score_id])
print("Best scores: ", scores_list[best_score_ids])
# Out:
# Best labels:
# grasp
# wrap_grasp
# pourable
# contain
# Best scores:  [ 68.00398 199.07465 205.49992 235.93713]

# %%
pcd_0 = o3d.geometry.PointCloud()
pcd_0.points = o3d.utility.Vector3dVector(pcl)
pcd_0.paint_uniform_color([0, 0, 0])
np.asarray(pcd_0.colors)[labels_list[best_score_ids[0]].squeeze() > 0] = [1, 0, 0]
draw([pcd_0], title="Label: " + list(data_temp['data_info']['label'].keys())[best_score_ids[0]])

pcd_1 = o3d.geometry.PointCloud()
pcd_1.points = o3d.utility.Vector3dVector(pcl)
pcd_1.paint_uniform_color([0, 0, 0])
np.asarray(pcd_1.colors)[labels_list[best_score_ids[1]].squeeze() > 0] = [0, 1, 0]
draw([pcd_1], title="Label: " + list(data_temp['data_info']['label'].keys())[best_score_ids[1]])

pcd_2 = o3d.geometry.PointCloud()
pcd_2.points = o3d.utility.Vector3dVector(pcl)
pcd_2.paint_uniform_color([0, 0, 0])
np.asarray(pcd_2.colors)[labels_list[best_score_ids[2]].squeeze() > 0] = [0, 0, 1]
draw([pcd_2], title="Label: " + list(data_temp['data_info']['label'].keys())[best_score_ids[2]])

pcd_3 = o3d.geometry.PointCloud()
pcd_3.points = o3d.utility.Vector3dVector(pcl)
pcd_3.paint_uniform_color([0, 0, 0])
np.asarray(pcd_3.colors)[labels_list[best_score_ids[3]].squeeze() > 0] = [1, 1, 0]
draw([pcd_3], title="Label: " + list(data_temp['data_info']['label'].keys())[best_score_ids[3]])
# Out:
# [Open3D INFO] Window window_33 created.
# WebVisualizer(window_uid='window_33')
# [Open3D INFO] Window window_34 created.
# WebVisualizer(window_uid='window_34')
# [Open3D INFO] Window window_35 created.
# WebVisualizer(window_uid='window_35')
# [Open3D INFO] Window window_36 created.
# WebVisualizer(window_uid='window_36')
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceServers
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceServers
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceServers
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/call
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/call
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/call
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceServers
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] DataChannelObserver::OnStateChange label: ServerDataChannel, state: open, peerid: 0.01588552042400848
# [Open3D INFO] DataChannelObserver::OnStateChange label: ClientDataChannel, state: open, peerid: 0.01588552042400848
# [Open3D INFO] Sending init frames to window_33.
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [1650:798][11089] (stun_port.cc:96): Binding request timed out from 130.83.164.x:53338 (enp5s0)
# [Open3D INFO] DataChannelObserver::OnStateChange label: ServerDataChannel, state: open, peerid: 0.05860516265367588
# [Open3D INFO] DataChannelObserver::OnStateChange label: ClientDataChannel, state: open, peerid: 0.05860516265367588
# [Open3D INFO] Sending init frames to window_34.
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/call
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceCandidate
# [Open3D INFO] DataChannelObserver::OnStateChange label: ServerDataChannel, state: open, peerid: 0.7369151970921259
# [Open3D INFO] DataChannelObserver::OnStateChange label: ClientDataChannel, state: open, peerid: 0.7369151970921259
# [Open3D INFO] Sending init frames to window_35.
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] DataChannelObserver::OnStateChange label: ServerDataChannel, state: open, peerid: 0.9346665576464468
# [Open3D INFO] DataChannelObserver::OnStateChange label: ClientDataChannel, state: open, peerid: 0.9346665576464468
# [Open3D INFO] Sending init frames to window_36.
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/addIceCandidate
# [Open3D INFO] [Called HTTP API (custom handshake)] /api/getIceCandidate
# [1653:270][11089] (stun_port.cc:96): Binding request timed out from 130.83.164.x:39043 (enp5s0)
# [1653:276][11089] (stun_port.cc:96): Binding request timed out from 130.83.164.x:41140 (enp5s0)
# [1653:279][11089] (stun_port.cc:96): Binding request timed out from 130.83.164.x:47451 (enp5s0)
# [1653:285][11089] (stun_port.cc:96): Binding request timed out from 130.83.164.x:38871 (enp5s0)
